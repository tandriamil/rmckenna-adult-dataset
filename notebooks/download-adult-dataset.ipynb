# %% [markdown]
# # Download the adult dataset
#
# This notebook downloads the
# [adult dataset](https://archive.ics.uci.edu/ml/datasets/adult) using the
# [ucimlrepo](github.com/uci-ml-repo/ucimlrepo) tool. We do this to avoid
# downloading it on each call to `fetch_ucirepo`.

# %%
from pathlib import Path
from ucimlrepo import fetch_ucirepo

ADULT_DATASET_ID = 2

DATA_PATH = Path('../data')
assert DATA_PATH.is_dir()

# %% [markdown]
# ## Download the dataset

# %%
adult = fetch_ucirepo(id=ADULT_DATASET_ID)

# %% [markdown]
# ## Limit to the features
#
# The dataset comes with the metadata and the target variables to predict. For
# our use case, **we only use the features**.

# %%
dataset = adult.data.original
dataset.sample(10)
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 1904    39    Private  179271  Some-college             10
# 44024   38  Local-gov  218763       Masters             14
# 18448   54    Private  378747          10th              6
# 46886   47  Local-gov  336274       HS-grad              9
# 37356   36    Private  166855       7th-8th              4
# 2617    23    Private  241185       HS-grad              9
# 45875   61        NaN  270599       1st-4th              2
# 25213   35    Private  187329     Bachelors             13
# 3763    24    Private   23438     Assoc-voc             11
# 47554   17    Private  153021  Some-college             10
#
#            marital-status         occupation   relationship   race     sex  \
# 1904   Married-civ-spouse       Craft-repair        Husband  White    Male
# 44024           Separated     Prof-specialty      Unmarried  White  Female
# 18448           Separated   Transport-moving      Unmarried  Black    Male
# 46886            Divorced      Other-service  Not-in-family  White  Female
# 37356            Divorced  Machine-op-inspct  Not-in-family  White  Female
# 2617        Never-married       Adm-clerical  Not-in-family  White  Female
# 45875             Widowed                NaN  Not-in-family  White  Female
# 25213       Never-married     Prof-specialty  Not-in-family  White  Female
# 3763        Never-married       Adm-clerical  Not-in-family  White    Male
# 47554       Never-married       Adm-clerical      Own-child  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country  income
# 1904              0             0              50  United-States    >50K
# 44024             0             0              40  United-States  <=50K.
# 18448             0             0              45  United-States    >50K
# 46886             0             0              40  United-States  <=50K.
# 37356             0             0              40  United-States  <=50K.
# 2617              0             0              40  United-States   <=50K
# 45875             0             0              18         Mexico  <=50K.
# 25213             0             0              40  United-States   <=50K
# 3763              0             0              30  United-States    >50K
# 47554             0             0               6  United-States  <=50K.

# %% [markdown]
# ## Save the dataset

# %%
dataset_path = DATA_PATH / Path('adult-dataset-pickle.zip')
dataset.to_pickle(dataset_path)
