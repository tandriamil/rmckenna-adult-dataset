# %% [markdown]
# # Download the adult dataset
#
# This notebook downloads the
# [adult dataset](https://archive.ics.uci.edu/ml/datasets/adult) using the
# [ucimlrepo](github.com/uci-ml-repo/ucimlrepo) tool. We do this to avoid
# downloading it on each call to `fetch_ucirepo`.

# %%
from pathlib import Path
from ucimlrepo import fetch_ucirepo

ADULT_DATASET_ID = 2

DATA_PATH = Path('../data')
assert DATA_PATH.is_dir()

# %% [markdown]
# ## Download the dataset

# %%
adult = fetch_ucirepo(id=ADULT_DATASET_ID)

# %% [markdown]
# ## Limit to the features
#
# The dataset comes with the metadata and the target variables to predict. For
# our use case, **we only use the features**.

# %%
dataset = adult.data.original
dataset.sample(10)
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 44410   27    Private  110663       HS-grad              9
# 45190   38    Private  589809     Bachelors             13
# 27500   40    Private  262872     Bachelors             13
# 7510    62          ?  225657       HS-grad              9
# 17577   43    Private   74581       HS-grad              9
# 14597   38    Private  187999     Bachelors             13
# 45943   38    Private  184456  Some-college             10
# 5119    39  State-gov  121838       HS-grad              9
# 31031   53    Private  142411     Assoc-voc             11
# 33850   30  State-gov  184901     Bachelors             13
#
#            marital-status       occupation   relationship   race     sex  \
# 44410  Married-civ-spouse            Sales        Husband  White    Male
# 45190  Married-civ-spouse     Adm-clerical        Husband  White    Male
# 27500       Never-married     Adm-clerical  Not-in-family  White  Female
# 7510   Married-civ-spouse                ?        Husband  White    Male
# 17577  Married-civ-spouse     Craft-repair        Husband  White    Male
# 14597  Married-civ-spouse     Tech-support        Husband  White    Male
# 45943       Never-married    Other-service  Not-in-family  White    Male
# 5119             Divorced    Other-service      Unmarried  Black  Female
# 31031            Divorced   Prof-specialty      Unmarried  White  Female
# 33850  Married-civ-spouse  Exec-managerial        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country  income
# 44410             0             0              50  United-States  <=50K.
# 45190             0             0              45  United-States   >50K.
# 27500             0             0              40  United-States   <=50K
# 7510              0             0              24  United-States   <=50K
# 17577             0             0              48  United-States    >50K
# 14597             0             0              45  United-States    >50K
# 45943             0             0              50         Greece  <=50K.
# 5119              0             0              40  United-States   <=50K
# 31031             0             0              40  United-States   <=50K
# 33850             0             0              40  United-States   >50K.

# %% [markdown]
# ## Save the dataset

# %%
dataset_path = DATA_PATH / Path('adult-dataset-pickle.zip')
dataset.to_pickle(dataset_path)
