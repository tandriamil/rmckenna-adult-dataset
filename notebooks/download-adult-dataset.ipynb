# %% [markdown]
# # Download the adult dataset
#
# This notebook downloads the
# [adult dataset](https://archive.ics.uci.edu/ml/datasets/adult) using the
# [ucimlrepo](github.com/uci-ml-repo/ucimlrepo) tool. We do this to avoid
# downloading it on each call to `fetch_ucirepo`.

# %%
from pathlib import Path
from ucimlrepo import fetch_ucirepo

ADULT_DATASET_ID = 2

DATA_PATH = Path('../data')
assert DATA_PATH.is_dir()

# %% [markdown]
# ## Download the dataset

# %%
adult = fetch_ucirepo(id=ADULT_DATASET_ID)

# %% [markdown]
# ## Limit to the features
#
# The dataset comes with the metadata and the target variables to predict. For
# our use case, **we only use the features**.

# %%
dataset = adult.data.original
dataset.sample(10)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7453    31           Private  185528  Some-college             10
# 1967    28           Private  291374       HS-grad              9
# 20074   46           Private  110171  Some-college             10
# 527     74           Private   99183  Some-college             10
# 46744   17           Private  181015          10th              6
# 12126   22           Private   60783          10th              6
# 23000   50           Private  217577       HS-grad              9
# 22596   51  Self-emp-not-inc  246820       HS-grad              9
# 22482   40           Private  164678    Assoc-acdm             12
# 6214    84  Self-emp-not-inc  155057     Bachelors             13
#
#            marital-status         occupation    relationship   race     sex  \
# 7453             Divorced              Sales       Own-child  White  Female
# 1967        Never-married       Adm-clerical       Unmarried  Black  Female
# 20074  Married-civ-spouse       Craft-repair         Husband  White    Male
# 527              Divorced       Adm-clerical   Not-in-family  White  Female
# 46744       Never-married      Other-service  Other-relative  White    Male
# 12126       Never-married       Craft-repair       Own-child  White    Male
# 23000             Widowed  Machine-op-inspct       Unmarried  White  Female
# 22596  Married-civ-spouse       Craft-repair         Husband  White    Male
# 22482            Divorced     Prof-specialty       Unmarried  White  Female
# 6214   Married-civ-spouse    Farming-fishing         Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country  income
# 7453              0             0              35  United-States   <=50K
# 1967              0             0              40  United-States   <=50K
# 20074          7688             0              40  United-States    >50K
# 527               0             0               9  United-States   <=50K
# 46744             0             0              15  United-States  <=50K.
# 12126             0             0              15  United-States   <=50K
# 23000             0             0              40  United-States   <=50K
# 22596          7298             0              48  United-States    >50K
# 22482             0             0              32  United-States   <=50K
# 6214              0             0              20  United-States   <=50K

# %% [markdown]
# ## Save the dataset

# %%
dataset_path = DATA_PATH / Path('adult-dataset-pickle.zip')
dataset.to_pickle(dataset_path)
